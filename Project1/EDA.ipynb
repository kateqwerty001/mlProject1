# %% [markdown]
# <h3>First, we have to separate 20% of records
# from our dataset in order to give it to our validation team</h3>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

all_data = pd.read_csv('data/credit_score.csv')

train, validation = train_test_split(all_data, test_size=0.2, stratify=all_data['DEFAULT'], random_state=10)

# %%
train.shape, validation.shape
# Out:
# ((800, 87), (200, 87))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(10,5))

sns.histplot(data=train, x = 'CREDIT_SCORE',bins = 30, ax=axes[0])
axes[0].set_title('Distribution of Credit Score in Train DataSet')
axes[0].set_xlim(300, 801)

sns.histplot(data=validation, x = 'CREDIT_SCORE',bins = 30, ax=axes[1])
axes[1].set_title('Distribution of Credit Score in Validation DataSet')
axes[1].set_xlim(300, 801)
# Out:
# (300.0, 801.0)

# %%
fig, axes = plt.subplots(1, 2,figsize=(10,5))

sns.histplot(data=train, x = 'DEFAULT',discrete=True, color='orange', ax=axes[0])
axes[0].set_xticks([0,1])
axes[0].set_title('Distribution of Default in Train DataSet')

sns.histplot(data=validation, x = 'DEFAULT',discrete=True, color='orange', ax=axes[1])
axes[1].set_xticks([0,1])
axes[1].set_title('Distribution of Default in Validation DataSet')
# Out:
# Text(0.5, 1.0, 'Distribution of Default in Validation DataSet')

# %% [markdown]
# So, our dataset is perfectly separated into 2 parts: our dataseet and dataset for our validation team

# %%
train.to_csv('data/data.csv', index=False)
validation.to_csv('data/validation.csv', index=False)

# %% [markdown]
# <h3>General information</h3>

# %%
data=pd.read_csv('data/data.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 87 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CUST_ID                  800 non-null    object
#  1   INCOME                   800 non-null    int64
#  2   SAVINGS                  800 non-null    int64
#  3   DEBT                     800 non-null    int64
#  4   R_SAVINGS_INCOME         800 non-null    float64
#  5   R_DEBT_INCOME            800 non-null    float64
#  6   R_DEBT_SAVINGS           800 non-null    float64
#  7   T_CLOTHING_12            800 non-null    int64
#  8   T_CLOTHING_6             800 non-null    int64
#  9   R_CLOTHING               800 non-null    float64
#  10  R_CLOTHING_INCOME        800 non-null    float64
#  11  R_CLOTHING_SAVINGS       800 non-null    float64
#  12  R_CLOTHING_DEBT          800 non-null    float64
#  13  T_EDUCATION_12           800 non-null    int64
#  14  T_EDUCATION_6            800 non-null    int64
#  15  R_EDUCATION              800 non-null    float64
#  16  R_EDUCATION_INCOME       800 non-null    float64
#  17  R_EDUCATION_SAVINGS      800 non-null    float64
#  18  R_EDUCATION_DEBT         800 non-null    float64
#  19  T_ENTERTAINMENT_12       800 non-null    int64
#  20  T_ENTERTAINMENT_6        800 non-null    int64
#  21  R_ENTERTAINMENT          800 non-null    float64
#  22  R_ENTERTAINMENT_INCOME   800 non-null    float64
#  23  R_ENTERTAINMENT_SAVINGS  800 non-null    float64
#  24  R_ENTERTAINMENT_DEBT     800 non-null    float64
#  25  T_FINES_12               800 non-null    int64
#  26  T_FINES_6                800 non-null    int64
#  27  R_FINES                  800 non-null    float64
#  28  R_FINES_INCOME           800 non-null    float64
#  29  R_FINES_SAVINGS          800 non-null    float64
#  30  R_FINES_DEBT             800 non-null    float64
#  31  T_GAMBLING_12            800 non-null    int64
#  32  T_GAMBLING_6             800 non-null    int64
#  33  R_GAMBLING               800 non-null    float64
#  34  R_GAMBLING_INCOME        800 non-null    float64
#  35  R_GAMBLING_SAVINGS       800 non-null    float64
#  36  R_GAMBLING_DEBT          800 non-null    float64
#  37  T_GROCERIES_12           800 non-null    int64
#  38  T_GROCERIES_6            800 non-null    int64
#  39  R_GROCERIES              800 non-null    float64
#  40  R_GROCERIES_INCOME       800 non-null    float64
#  41  R_GROCERIES_SAVINGS      800 non-null    float64
#  42  R_GROCERIES_DEBT         800 non-null    float64
#  43  T_HEALTH_12              800 non-null    int64
#  44  T_HEALTH_6               800 non-null    int64
#  45  R_HEALTH                 800 non-null    float64
#  46  R_HEALTH_INCOME          800 non-null    float64
#  47  R_HEALTH_SAVINGS         800 non-null    float64
#  48  R_HEALTH_DEBT            800 non-null    float64
#  49  T_HOUSING_12             800 non-null    int64
#  50  T_HOUSING_6              800 non-null    int64
#  51  R_HOUSING                800 non-null    float64
#  52  R_HOUSING_INCOME         800 non-null    float64
#  53  R_HOUSING_SAVINGS        800 non-null    float64
#  54  R_HOUSING_DEBT           800 non-null    float64
#  55  T_TAX_12                 800 non-null    int64
#  56  T_TAX_6                  800 non-null    int64
#  57  R_TAX                    800 non-null    float64
#  58  R_TAX_INCOME             800 non-null    float64
#  59  R_TAX_SAVINGS            800 non-null    float64
#  60  R_TAX_DEBT               800 non-null    float64
#  61  T_TRAVEL_12              800 non-null    int64
#  62  T_TRAVEL_6               800 non-null    int64
#  63  R_TRAVEL                 800 non-null    float64
#  64  R_TRAVEL_INCOME          800 non-null    float64
#  65  R_TRAVEL_SAVINGS         800 non-null    float64
#  66  R_TRAVEL_DEBT            800 non-null    float64
#  67  T_UTILITIES_12           800 non-null    int64
#  68  T_UTILITIES_6            800 non-null    int64
#  69  R_UTILITIES              800 non-null    float64
#  70  R_UTILITIES_INCOME       800 non-null    float64
#  71  R_UTILITIES_SAVINGS      800 non-null    float64
#  72  R_UTILITIES_DEBT         800 non-null    float64
#  73  T_EXPENDITURE_12         800 non-null    int64
#  74  T_EXPENDITURE_6          800 non-null    int64
#  75  R_EXPENDITURE            800 non-null    float64
#  76  R_EXPENDITURE_INCOME     800 non-null    float64
#  77  R_EXPENDITURE_SAVINGS    800 non-null    float64
#  78  R_EXPENDITURE_DEBT       800 non-null    float64
#  79  CAT_GAMBLING             800 non-null    object
#  80  CAT_DEBT                 800 non-null    int64
#  81  CAT_CREDIT_CARD          800 non-null    int64
#  82  CAT_MORTGAGE             800 non-null    int64
#  83  CAT_SAVINGS_ACCOUNT      800 non-null    int64
#  84  CAT_DEPENDENTS           800 non-null    int64
#  85  CREDIT_SCORE             800 non-null    int64
#  86  DEFAULT                  800 non-null    int64
# dtypes: float64(51), int64(34), object(2)
# memory usage: 543.9+ KB

# %% [markdown]
# <h3>Important information:</h3>
# <ul>
# <li>There are no NULLs in our dataset</li>
# <li>There are 87 columns (85 are numeric and 2(CUST_ID, CAT_GAMBLING) are object)</li>
# </ul>

# %% [markdown]
# <h3>Correlation matrix</h3>

# %%
cor_matrix = data.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
cor_matrix
# Out:
# /var/folders/y9/p941jysn0ddb8zkx38rpntd80000gn/T/ipykernel_39487/312261026.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor_matrix = data.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# /var/folders/y9/p941jysn0ddb8zkx38rpntd80000gn/T/ipykernel_39487/312261026.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   cor_matrix = data.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# %% [markdown]
# <p>There are several pairs of variables that are highly correlated with each other (correlation coefficient >=0.95).
# These variables are:
# <ul>
# <li> </li>
# <li> </li>
# <li> </li>
# <li> </li>
# </ul>
# </p>

# %% [markdown]
# <h3>Distributions of features</h3>

# %%
data.hist(figsize=(40,80), layout=(22, 4))
# Out:
# array([[<AxesSubplot: title={'center': 'INCOME'}>,
#         <AxesSubplot: title={'center': 'SAVINGS'}>,
#         <AxesSubplot: title={'center': 'DEBT'}>,
#         <AxesSubplot: title={'center': 'R_SAVINGS_INCOME'}>],
#        [<AxesSubplot: title={'center': 'R_DEBT_INCOME'}>,
#         <AxesSubplot: title={'center': 'R_DEBT_SAVINGS'}>,
#         <AxesSubplot: title={'center': 'T_CLOTHING_12'}>,
#         <AxesSubplot: title={'center': 'T_CLOTHING_6'}>],
#        [<AxesSubplot: title={'center': 'R_CLOTHING'}>,
#         <AxesSubplot: title={'center': 'R_CLOTHING_INCOME'}>,
#         <AxesSubplot: title={'center': 'R_CLOTHING_SAVINGS'}>,
#         <AxesSubplot: title={'center': 'R_CLOTHING_DEBT'}>],
#        [<AxesSubplot: title={'center': 'T_EDUCATION_12'}>,
#         <AxesSubplot: title={'center': 'T_EDUCATION_6'}>,
#         <AxesSubplot: title={'center': 'R_EDUCATION'}>,
#         <AxesSubplot: title={'center': 'R_EDUCATION_INCOME'}>],
#        [<AxesSubplot: title={'center': 'R_EDUCATION_SAVINGS'}>,
#         <AxesSubplot: title={'center': 'R_EDUCATION_DEBT'}>,
#         <AxesSubplot: title={'center': 'T_ENTERTAINMENT_12'}>,
#         <AxesSubplot: title={'center': 'T_ENTERTAINMENT_6'}>],
#        [<AxesSubplot: title={'center': 'R_ENTERTAINMENT'}>,
#         <AxesSubplot: title={'center': 'R_ENTERTAINMENT_INCOME'}>,
#         <AxesSubplot: title={'center': 'R_ENTERTAINMENT_SAVINGS'}>,
#         <AxesSubplot: title={'center': 'R_ENTERTAINMENT_DEBT'}>],
#        [<AxesSubplot: title={'center': 'T_FINES_12'}>,
#         <AxesSubplot: title={'center': 'T_FINES_6'}>,
#         <AxesSubplot: title={'center': 'R_FINES'}>,
#         <AxesSubplot: title={'center': 'R_FINES_INCOME'}>],
#        [<AxesSubplot: title={'center': 'R_FINES_SAVINGS'}>,
#         <AxesSubplot: title={'center': 'R_FINES_DEBT'}>,
#         <AxesSubplot: title={'center': 'T_GAMBLING_12'}>,
#         <AxesSubplot: title={'center': 'T_GAMBLING_6'}>],
#        [<AxesSubplot: title={'center': 'R_GAMBLING'}>,
#         <AxesSubplot: title={'center': 'R_GAMBLING_INCOME'}>,
#         <AxesSubplot: title={'center': 'R_GAMBLING_SAVINGS'}>,
#         <AxesSubplot: title={'center': 'R_GAMBLING_DEBT'}>],
#        [<AxesSubplot: title={'center': 'T_GROCERIES_12'}>,
#         <AxesSubplot: title={'center': 'T_GROCERIES_6'}>,
#         <AxesSubplot: title={'center': 'R_GROCERIES'}>,
#         <AxesSubplot: title={'center': 'R_GROCERIES_INCOME'}>],
#        [<AxesSubplot: title={'center': 'R_GROCERIES_SAVINGS'}>,
#         <AxesSubplot: title={'center': 'R_GROCERIES_DEBT'}>,
#         <AxesSubplot: title={'center': 'T_HEALTH_12'}>,
#         <AxesSubplot: title={'center': 'T_HEALTH_6'}>],
#        [<AxesSubplot: title={'center': 'R_HEALTH'}>,
#         <AxesSubplot: title={'center': 'R_HEALTH_INCOME'}>,
#         <AxesSubplot: title={'center': 'R_HEALTH_SAVINGS'}>,
#         <AxesSubplot: title={'center': 'R_HEALTH_DEBT'}>],
#        [<AxesSubplot: title={'center': 'T_HOUSING_12'}>,
#         <AxesSubplot: title={'center': 'T_HOUSING_6'}>,
#         <AxesSubplot: title={'center': 'R_HOUSING'}>,
#         <AxesSubplot: title={'center': 'R_HOUSING_INCOME'}>],
#        [<AxesSubplot: title={'center': 'R_HOUSING_SAVINGS'}>,
#         <AxesSubplot: title={'center': 'R_HOUSING_DEBT'}>,
#         <AxesSubplot: title={'center': 'T_TAX_12'}>,
#         <AxesSubplot: title={'center': 'T_TAX_6'}>],
#        [<AxesSubplot: title={'center': 'R_TAX'}>,
#         <AxesSubplot: title={'center': 'R_TAX_INCOME'}>,
#         <AxesSubplot: title={'center': 'R_TAX_SAVINGS'}>,
#         <AxesSubplot: title={'center': 'R_TAX_DEBT'}>],
#        [<AxesSubplot: title={'center': 'T_TRAVEL_12'}>,
#         <AxesSubplot: title={'center': 'T_TRAVEL_6'}>,
#         <AxesSubplot: title={'center': 'R_TRAVEL'}>,
#         <AxesSubplot: title={'center': 'R_TRAVEL_INCOME'}>],
#        [<AxesSubplot: title={'center': 'R_TRAVEL_SAVINGS'}>,
#         <AxesSubplot: title={'center': 'R_TRAVEL_DEBT'}>,
#         <AxesSubplot: title={'center': 'T_UTILITIES_12'}>,
#         <AxesSubplot: title={'center': 'T_UTILITIES_6'}>],
#        [<AxesSubplot: title={'center': 'R_UTILITIES'}>,
#         <AxesSubplot: title={'center': 'R_UTILITIES_INCOME'}>,
#         <AxesSubplot: title={'center': 'R_UTILITIES_SAVINGS'}>,
#         <AxesSubplot: title={'center': 'R_UTILITIES_DEBT'}>],
#        [<AxesSubplot: title={'center': 'T_EXPENDITURE_12'}>,
#         <AxesSubplot: title={'center': 'T_EXPENDITURE_6'}>,
#         <AxesSubplot: title={'center': 'R_EXPENDITURE'}>,
#         <AxesSubplot: title={'center': 'R_EXPENDITURE_INCOME'}>],
#        [<AxesSubplot: title={'center': 'R_EXPENDITURE_SAVINGS'}>,
#         <AxesSubplot: title={'center': 'R_EXPENDITURE_DEBT'}>,
#         <AxesSubplot: title={'center': 'CAT_DEBT'}>,
#         <AxesSubplot: title={'center': 'CAT_CREDIT_CARD'}>],
#        [<AxesSubplot: title={'center': 'CAT_MORTGAGE'}>,
#         <AxesSubplot: title={'center': 'CAT_SAVINGS_ACCOUNT'}>,
#         <AxesSubplot: title={'center': 'CAT_DEPENDENTS'}>,
#         <AxesSubplot: title={'center': 'CREDIT_SCORE'}>],
#        [<AxesSubplot: title={'center': 'DEFAULT'}>, <AxesSubplot: >,
#         <AxesSubplot: >, <AxesSubplot: >]], dtype=object)

# %% [markdown]
# <p>Results from this distribution plots:</p>
# <ul>
# <li> </li>
# <li> </li>
# <li> </li>
# <li> </li>
# </ul>
# </p>

# %% [markdown]
# <h3>Do people with dependents spend more money on education than people without dependents?</h3>
